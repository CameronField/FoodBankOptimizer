# %%
#pip install gurobipy==10

# %%
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

# %%
# --------------- User-defined Parameters --------------- #
# Define your parameters here, for example:
M = 100000  # Maximum meals delivered by a bank in a two-week period.
D = 75  # Maximum distance a person can travel from their home to a pantry in miles.
P_min = 0.15  # Minimum percent of the FI population that must be served.
Budget = 5000000  # Total budget for the network.
Cost_per_meal_per_mile = 0.05  # Average cost per mile to transport food from a bank to a pantry.
Meals_Per_Person = 20

# %%
# Read the input data from the CSV files
banks_df = pd.read_csv('MSBankLatLong.csv')
pantries_df = pd.read_csv('MSPantryLatLong.csv')
demand_df = pd.read_csv('MSDemandLatLong.csv')
bank_to_pantry_distance_df = pd.read_csv('BankToPantryDistanceMatrix.csv', index_col=0)
pantry_to_demand_distance_df = pd.read_csv('PantryToDemandDistanceMatrix.csv', index_col=0)

# %%
#Debugging 

# Check for matching column names in the distance DataFrame and the county names
print(set(pantry_to_demand_distance_df.columns) == set(demand_df['County']))

# Try accessing a specific element
example_pantry = pantries_df['Name'].iloc[50]
example_county = demand_df['County'].iloc[70]
print("Accessing distance for:", example_pantry, "and", example_county)
print(pantry_to_demand_distance_df.loc[example_pantry, example_county])

# Check data types after conversion to numeric
print(pantry_to_demand_distance_df.dtypes)
print(pantry_to_demand_distance_df.loc["Society of St. Vincent de Paul and Nativity of the Blessed Virgin Mary Conference", "Tishomingo County"])
# Out:
# True
# Accessing distance for: Society of St. Vincent de Paul and Nativity of the Blessed Virgin Mary Conference and Tishomingo County
# 336.3782818
# Adams County        float64
# Alcorn County       float64
# Amite County        float64
# Attala County       float64
# Benton County       float64
#                      ...
# Webster County      float64
# Wilkinson County    float64
# Winston County      float64
# Yalobusha County    float64
# Yazoo County        float64
# Length: 82, dtype: object
# 336.3782818

# %%
#More debugging
# Ensure that the values are numeric and check for missing values
print(pantry_to_demand_distance_df.isnull().any().any())

# Verify that D is a numeric value
print("D:", D)

# Try accessing a specific element
example_pantry = pantries_df['Name'].iloc[0]
example_county = demand_df['County'].iloc[0]
print("Accessing distance for:", example_pantry, "and", example_county)
print(pantry_to_demand_distance_df.loc[example_pantry, example_county])
# Out:
# False
# D: 75
# Accessing distance for: Stewpot and Adams County
# 7.191544281

# %%
FI_population_df = demand_df[['County', 'FI Population 2021']].set_index('County')
#FI_population_df
FI_population_df.loc["Adams County", "FI Population 2021"]
# Out:
# '5,530'

# %%
# Initialize the model
model = gp.Model("Food_Distribution_Optimization")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-01

# %%
# Decision Variables

# x_bp: Amount of food delivered from bank b to pantry p.
x_bp = model.addVars(banks_df['Name'], pantries_df['Name'], vtype=GRB.INTEGER, name="x_bp")


# y_pc: Amount of FI persons fed from pantry p to demand node c.
y_pc = model.addVars(pantries_df["Name"], demand_df["County"], vtype=GRB.INTEGER, name="y_pc")

# %%
# Constraints
# Bank delivery constraint
model.addConstrs((gp.quicksum(x_bp[b, p] for p in pantries_df['Name']) <= M for b in banks_df['Name']), name='bank_delivery')

# Distance constraint for pantries
model.addConstrs((pantry_to_demand_distance_df.loc[p, c]*y_pc[p,c] <= D*y_pc[p,c] for p in pantries_df['Name'] for c in demand_df['County']), name='pantry_distance')

# P_min constraint: Each county must have at least P_min percent of its food insecure people fed
FI_population_df = demand_df[['County', 'FI Population 2021']].set_index('County')
for c in demand_df['County']:
    total_fi_population = FI_population_df.loc[c, 'FI Population 2021']
    total_fi_population = int(total_fi_population.replace(',', ''))  
    model.addConstr(gp.quicksum(y_pc[p, c] for p in pantries_df['Name']) >= P_min * total_fi_population, name=f'P_min_constraint_{c}')

# Budget constraint
total_transport_cost = gp.quicksum(x_bp[b, p] * bank_to_pantry_distance_df.loc[b, p] * Cost_per_meal_per_mile 
                                   for b in banks_df['Name'] for p in pantries_df['Name'])
meal_cost_df = demand_df[['County', '2021 Cost Per Meal']].set_index('County')
total_procurement_cost = gp.quicksum(y_pc[p, c] * meal_cost_df.loc[c, '2021 Cost Per Meal'] 
                                     for p in pantries_df['Name'] for c in demand_df['County'])

total_cost = total_transport_cost + total_procurement_cost
model.addConstr(total_cost <= Budget, name='budget')

# Meals per person constraint
for p in pantries_df['Name']:
    for c in demand_df['County']:
        model.addConstr(y_pc[p, c] * Meals_Per_Person <= x_bp.sum('*', p), name=f'meals_per_person_constraint_{p}_{c}')

# Supply and demand constraint
model.addConstrs((gp.quicksum(y_pc[p, c] for c in demand_df['County']) <= gp.quicksum(x_bp[b, p] for b in banks_df['Name']) for p in pantries_df['Name']), name='supply_demand')

# Demand fulfillment constraint
model.addConstrs((y_pc[p, c] <= M for p in pantries_df['Name'] for c in demand_df['County']), name='demand_fulfillment')

# Non-negativity constraint
model.addConstrs((x_bp[b, p] >= 0 for b in banks_df['Name'] for p in pantries_df['Name']), name='non-negativity_x')
model.addConstrs((y_pc[p, c] >= 0 for p in pantries_df['Name'] for c in demand_df['County']), name='non-negativity_y')
# Out:
# {('Stewpot', 'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Stewpot', 'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Rose Hill Baptist Church',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Pilgrim Baptist Church',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('First Assembly of God',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('61 South Church of Christ',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities', 'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Catholic Charities',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('King’s Kabinet Food Pantry',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
# ...
#  ('Helping Hands of Cleveland',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('Helping Hands of Cleveland',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'DeSoto County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Forrest County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Franklin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'George County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Greene County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Grenada County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Hancock County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Harrison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Hinds County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Holmes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Humphreys County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Issaquena County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Itawamba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Jackson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Jasper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Jefferson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Jefferson Davis County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Jones County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Kemper County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lafayette County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lamar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lauderdale County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lawrence County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Leake County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Leflore County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lincoln County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Lowndes County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Madison County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Marion County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Marshall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Monroe County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Montgomery County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Neshoba County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Newton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Noxubee County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Oktibbeha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Panola County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Pearl River County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Perry County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Pike County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Pontotoc County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Prentiss County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Quitman County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Rankin County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Scott County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Sharkey County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Simpson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Smith County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Stone County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Sunflower County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Tallahatchie County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Tate County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Tippah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Tishomingo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Tunica County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Union County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Walthall County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Warren County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Washington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Wayne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Webster County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Wilkinson County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Winston County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Yalobusha County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St. Gabriel Mercy Center Food Pantry',
#   'Yazoo County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Adams County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Alcorn County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Amite County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Attala County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Benton County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Bolivar County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Calhoun County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Carroll County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Chickasaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Choctaw County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Claiborne County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Clarke County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Clay County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Coahoma County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Copiah County'): <gurobi.Constr *Awaiting Model Update*>,
#  ('St Luke the Evangelist',
#   'Covington County'): <gurobi.Constr *Awaiting Model Update*>,
#  ...}

# %%
# Objective Function
model.setObjective(gp.quicksum(y_pc[p, c] for p in pantries_df['Name'] for c in demand_df["County"]), GRB.MAXIMIZE)

# %%
# Optimize the model
model.optimize()
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 73790 rows, 18870 columns and 184704 nonzeros
# Model fingerprint: 0xe3c926f1
# Variable types: 0 continuous, 18870 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 4e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 5e+06]
# Presolve removed 70280 rows and 15002 columns
# Presolve time: 0.15s
# Presolved: 3510 rows, 3868 columns, 24412 nonzeros
# Variable types: 0 continuous, 3868 integer (0 binary)
#
# Root relaxation: objective 2.574760e+05, 5386 iterations, 0.10 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    257476.00000 257476.000  0.00%     -    0s
#
# Explored 1 nodes (5386 simplex iterations) in 0.35 seconds (0.23 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 257476
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.574760000000e+05, best bound 2.574760000000e+05, gap 0.0000%

# %%
# Extract and print the results
solution_x_bp = model.getAttr('X', x_bp)
solution_y_pc = model.getAttr('X', y_pc)

for b, p in solution_x_bp.keys():
    if solution_x_bp[b, p] > 0:
        print(f"Bank {b} delivers {solution_x_bp[b, p]} meals to Pantry {p}.")
# Out:
# Bank Mississippi Food Network delivers 29000.0 meals to Pantry The Pantry.
# Bank Mississippi Food Network delivers 18780.0 meals to Pantry FAITH Food Pantry.
# Bank Mississippi Food Network delivers 16600.0 meals to Pantry Sam’s Diner & Food Pantry.
# Bank Mississippi Food Network delivers 1620.0 meals to Pantry Ephesus Baptist Church.
# Bank Mississippi Food Network delivers 4500.0 meals to Pantry Anguilla Methodist Church.
# Bank Mississippi Food Network delivers 29500.0 meals to Pantry Simpson Baptist Association.
# Bank Mid South Food Bank delivers 38060.0 meals to Pantry Edwards Street Fellowship Center Food Pantry.
# Bank Mid South Food Bank delivers 13980.0 meals to Pantry Greenwood Interfaith Ministries Community Kitchen.
# Bank Mid South Food Bank delivers 4800.0 meals to Pantry Mission Hope.
# Bank Mid South Food Bank delivers 33500.0 meals to Pantry Our Daily Bread Food Pantry Wiggins.
# Bank Mid South Food Bank delivers 9660.0 meals to Pantry Storehouse Community Food Pantry.
# Bank Feeding The Gulf Coast delivers 30100.0 meals to Pantry The Pantry.
# Bank Feeding The Gulf Coast delivers 33280.0 meals to Pantry Ever Reaching Community Outreach.
# Bank Feeding The Gulf Coast delivers 33500.0 meals to Pantry Our Daily Bread Food Pantry Wiggins.
# Bank Feeding The Gulf Coast delivers 3120.0 meals to Pantry Unity MB Church Food Pantry.

# %%
for p, c in solution_y_pc.keys():
    if solution_y_pc[p, c] > 0:
        print(f"Pantry {p} feeds {solution_y_pc[p, c]} FI persons in County {c}.")
# Out:
# Pantry Edwards Street Fellowship Center Food Pantry feeds 1903.0 FI persons in County